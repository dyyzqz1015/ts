# %%
# %pylab
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
# %matplotlib inline

# %%
x=linspace(0,2*pi,50)
plot(sin(x))

# %%
plot(x,sin(x))

# %%
plot(x,sin(x),x,sin(2*x))

# %%
plot(x,sin(x),"r-^")

# %%
plot(x,sin(x),'b-o',x,sin(2*x),'r-^')

# %%
plot(x,sin(x),'bo')

# %%
scatter(x,sin(x))

# %%
x=rand(200)
y=rand(200)
size=rand(200)*30
color=rand(200)
scatter=(x,y,size,color)
colorbar()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-d5715a441bab> in <module>()
#       4 color=rand(200)
#       5 scatter=(x,y,size,color)
# ----> 6 colorbar()
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2228         mappable = gci()
#    2229         if mappable is None:
# -> 2230             raise RuntimeError('No mappable was found to use for colorbar '
#    2231                                'creation. First define a mappable such as '
#    2232                                'an image (with imshow) or a contour set ('
#
# RuntimeError: No mappable was found to use for colorbar creation. First define a mappable such as an image (with imshow) or a contour set (with contourf).

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-0423e944f920> in <module>()
# ----> 1 scatter(x,sin(x))
#
# TypeError: 'tuple' object is not callable
