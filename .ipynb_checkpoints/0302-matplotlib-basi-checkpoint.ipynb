# %%
# %pylab

# %%
# %matplotlib inline

# %%
x=linspace(0,2*pi,50)
plot(sin(x))

# %%
plot(x,sin(x))

# %%
plot(x,sin(x),x,sin(2*x))

# %%
plot(x,sin(x),"r-^")

# %%
plot(x,sin(x),'b-o',x,sin(2*x),'r-^')

# %%
plot(x,sin(x),'bo')

# %%
scatter(x,sin(x))

# %%
x=rand(200)
y=rand(200)
size=rand(200)*30
color=rand(200)
scatter=(x,y,size,color)

# %%
scatter(x,sin(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0423e944f920> in <module>()
# ----> 1 scatter(x,sin(x))
#
# NameError: name 'scatter' is not defined
